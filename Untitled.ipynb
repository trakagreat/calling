# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("Book.xlsx")

# %%
df2 = pd.read_excel("icot 2017.xlsx")

# %%
df1.head()
# Out:
#           name    conatact
# 0    trivendra  8319845403
# 1    rajvendra  8109204371
# 2  sakhee devi  9827688768
# 3     ravindra  9628877872

# %%
df2.head()
# Out:
#   Unnamed: 0      Unnamed: 1         Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0        NaN             NaN          ICOT-POLY          NaN         NaN
# 1        NaN             NaN             BHOPAL          NaN         NaN
# 2       S No  Enrollment No.       Student Name  Scholar No.  Batch Year
# 3          1               -  BIBEK KUMAR RAJAK        13053   2017-2018
# 4          2     17130C03001        AAMIR NAWAZ        11988   2017-2018
#
#   Unnamed: 5    Unnamed: 6 Unnamed: 7     Unnamed: 8    Unnamed: 9  ...  \
# 0        NaN           NaN        NaN            NaN           NaN  ...
# 1        NaN           NaN        NaN            NaN           NaN  ...
# 2     Course        Branch   T.G.Name  T.G. MobileNo  Current Year  ...
# 3    DIPLOMA  DIPLOMA (EC)        NaN              0        I YEAR  ...
# 4    DIPLOMA  DIPLOMA (CE)        NaN              0       II YEAR  ...
#
#           Unnamed: 100            Unnamed: 101              Unnamed: 102  \
# ...

# %%
df2.dropna(axis=1, how='all',inplace=True)
df2.dropna(axis=0, how="all",inplace=True)
df2.fillna("",inplace=True)

# %%
df1.dropna(axis=1, how='all')
df1.dropna(axis=0, how="all")
df1.fillna("")
# Out:
#           name    conatact
# 0    trivendra  8319845403
# 1    rajvendra  8109204371
# 2  sakhee devi  9827688768
# 3     ravindra  9628877872

# %%
df3 = df2[3:].reset_index()
df3.index = list(range(1,len(df3)+1))
df3.index
df3
# Out:
# 2    index S No Enrollment No.        Student Name Scholar No. Batch Year  \
# 1        4    1              -   BIBEK KUMAR RAJAK       13053  2017-2018
# 2        5    2    17130C03001         AAMIR NAWAZ       11988  2017-2018
# 3        6    3    17130C03002            ABID ALI       11993  2017-2018
# 4        7    4    17130C03003      ADITYA VINAYAK       11996  2017-2018
# 5        8    5    17130C03004       AFZAL HUSSAIN       11998  2017-2018
# ..     ...  ...            ...                 ...         ...        ...
# 236    239  236    17130M02117        VINIT RANJAN       12212  2017-2018
# 237    240  237    17130M02118  VISHAL KUMAR SINGH       12213  2017-2018
# 238    241  238    17130M02119    VISHVAJEET SINGH       12214  2017-2018
# 239    242  239    17130M02120        WASIF ANSARI       12218  2017-2018
# 240    243  240     17130M2105   SUMIT KUMAR YADAV       12190  2017-2018
#
# 2     Course        Branch T.G.Name T.G. MobileNo  ... PET Exam Mark Total  \
# ...

# %%
# Out:
# 4     2  17130C03001  AAMIR NAWAZ  11988  2017-2018  DIPLOMA  DIPLOMA (CE)  \
# 0   NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 1   NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 2   NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 3   NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 4   NaN          NaN          NaN    NaN        NaN      NaN           NaN
# ..   ..          ...          ...    ...        ...      ...           ...
# 238 NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 239 NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 240 NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 241 NaN          NaN          NaN    NaN        NaN      NaN           NaN
# 242 NaN          NaN          NaN    NaN        NaN      NaN           NaN
#
# 4         0  II YEAR  ...   0   0   0  \
# ...

# %%
list(range(2))
# Out:
# [0, 1]
